# %% [markdown]
# # Herramientas básicas para el Análisis de Datos (IMA602)
#
# * **Walter Gómez Bofill**
#
#
# * **Minor Análisis de Datos**
#
#
# * **Primer semestre de 2024**

# %% [markdown]
# # Estructura del curso
#
# * Módulo Python
# * Módulo Probabilidades
#
# * Adicionalmente: Problema de Aprendizaje, Git, Control de versiones.
#
#
# * Los módulos pueden aprobarse con una prueba única (sin asitir a los mismos) o con los controles realizados periodicamente.

# %% [markdown]
# # Tipo de Aprendizaje
#
# * Aprendizaje supervisado
# * Aprendizaje no supervisado
# * Aprendizaje reforzado

# %% [markdown]
# # Descripción del problema de aprendizaje (supervisado)
#
# Imagenes del libro "Learning from Data" de Abu-Mostafa, Amgdon-Ismail y Lin (2012)

# %%
from IPython.display import Image

Image(filename=r'Imagenes_Clase_01/Fig_1_2.jpg', width=700)

# %%
from IPython.display import Image

Image(filename=r'Imagenes_Clase_01/Fig_1_9.png', width=700)

# %%
from IPython.display import Image

Image(filename=r'Imagenes_Clase_01/Fig_1_11.png', width=700)

# %% [markdown]
# # Modulo Python
#
# ## Contenidos (5 semanas)
#
#
# * **Paquete Anaconda (Python)**
#
#
# * **Objetos y datos básicos de Python**
#
# <!---    * Variables numéricas --->
#
# <!---    * Strings y Tuplas --->
#
# <!---     * Listas
#
# <!---    * Diccionarios y Conjuntos--->
#
#
# * **Programación Funcional con Python**
#
#
# * **Programación Orientada a Objetos con Python**
#
#
# * **Librería NumPy**
#
#
# * **Librería Pandas**
#
#
# * **Visualización de Datos**
#
# <!---     * Librerías Matplotlib y Seaborn--->
#
#
# ### Instalación Anaconda
#
# https://www.anaconda.com/distribution/
#
# ### Entorno Virtual
#
# * Crear: *conda create -n nombre python=3.8*
#
#
# * Activar: *conda activate nombre*
#
#
# * Desactivar: *conda deactivate*
#
# * listar: conda env list
# (entornos virtuales disponibles)
#
# más información: https://unipython.com/entornos-virtuales-en-python-y-anaconda/
#
#
# * Eliminar entorno virtual: *conda env remove -n nombre*
#
# más información: https://interactivechaos.com/es/conda/command/eliminacion-de-un-entorno
#
# ### Instalación librerias
#
# *pip install nombre_librería*
#
# *pip install nombre_librería_versión*
#
# **Versión librerías**: *pip list*
#
# ### Google Colab
#
# Enlace: https://colab.research.google.com/

# %% [markdown]
# # Variables Numéricas
#
# * **Tipo *int***

# %%
x = int(5)
print(type(x))
# Out:
# <class 'int'>

# %%
x = 5
print(type(x))
# Out:
# <class 'int'>

# %%
y = 10
print(x + y)
print(type(x + y))
# Out:
# 15
# <class 'int'>

# %%
print(x - 10)
print(type(x - 10))
# Out:
# -5
# <class 'int'>

# %% [markdown]
# * **Tipo *float***

# %%
z = x / y
print(z)
print(type(z))
# Out:
# 0.5
# <class 'float'>

# %%
x = 5.
print(type(x))
# Out:
# <class 'float'>

# %%
x = float(5)
print(type(x))
# Out:
# <class 'float'>

# %%
pi = 3.14
print(pi)
b = 30e-1
print(b)
# Out:
# 3.14
# 3.0

# %%
b + int(3)
# Out:
# 6.0

# %% [markdown]
# * **Tipo *complex***

# %%
z = 3.5 + 5.2j
z
# Out:
# (3.5+5.2j)

# %%
type(z)
# Out:
# complex

# %%
z = 3 + 5j
z
# Out:
# (3+5j)

# %%
type(z)
# Out:
# complex

# %%
z1 = -3.5 - 1j
z + z1
# Out:
# (-0.5+4j)

# %%
z / z1
# Out:
# (-1.1698113207547172-1.0943396226415096j)

# %%
z / x
# Out:
# (0.6+1j)

# %%
print(z.real)
print(z.imag)
print(z.conjugate())
# Out:
# 3.0
# 5.0
# (3-5j)
